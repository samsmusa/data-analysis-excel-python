# %%
import pandas as pd
import numpy as np 
import matplotlib as plt

# %%
file = pd.read_excel("Section2_Formulas101cp.xlsx", sheet_name="Formula Syntax")

# %%
file.head(   )
# Out:
#                Name           Street Address         City State    Zip  \
# 0  Jennifer Mcgrath         985 Eagle Street      Fieldon    IL  62031
# 1        Chad Lewis         267 Francis Mine  Downieville    CA  95936
# 2   Susan Rodriguez  4620 Williams Mine Road    Maplewood    NJ   7040
# 3     Wayne Nielson     1829 White Pine Lane     Dahlgren    VA  22448
# 4       John Depaul     1165 Victoria Street  Baton Rouge    LA  70815
#
#   Birth Date  Birth Year     Telephone  Area Code  \
# 0 1999-07-27        1999  618-376-3064        618
# 1 1978-11-22        1978  530-289-3807        530
# 2 1957-12-24        1957  908-264-1670        908
# 3 1997-12-19        1997  540-644-7658        540
# 4 1967-08-27        1967  225-274-4802        225
#
#                           E-mail            Username
# 0   JenniferJMcGrath99@gmail.com  JenniferJMcGrath99
# 1           ChadSLewis51@aol.com        ChadSLewis51
# 2  SusanSRodriguez71@hotmail.com   SusanSRodriguez71
# ...

# %%
# insert birth year from "Birth Date" column
file["Birth Year"] = pd.DatetimeIndex(file["Birth Date"]).year

# %%
# insert area code from phone number first 3 digit
file['Area Code'] = file['Telephone'].str[:3]
file.head(1)
# Out:
#                Name    Street Address     City State    Zip Birth Date  \
# 0  Jennifer Mcgrath  985 Eagle Street  Fieldon    IL  62031 1999-07-27
#
#    Birth Year     Telephone Area Code                        E-mail  \
# 0        1999  618-376-3064       618  JenniferJMcGrath99@gmail.com
#
#              Username
# 0  JenniferJMcGrath99

# %%
file["Username"] = file["E-mail"].str.split("@").str[0]
file.head(10)
# Out:
#                  Name           Street Address              City State    Zip  \
# 0    Jennifer Mcgrath         985 Eagle Street           Fieldon    IL  62031
# 1          Chad Lewis         267 Francis Mine       Downieville    CA  95936
# 2     Susan Rodriguez  4620 Williams Mine Road         Maplewood    NJ   7040
# 3       Wayne Nielson     1829 White Pine Lane          Dahlgren    VA  22448
# 4         John Depaul     1165 Victoria Street       Baton Rouge    LA  70815
# 5     Joseph Martinez      3866 Mattson Street          Portland    OR  97205
# 6         Diane Henry         3902 Valley Lane            Austin    TX  78749
# 7  Veronica Comerford     3932 Franklin Street          Tuskegee    AL  36083
# 8       Beverly Nixon   3480 Dancing Dove Lane  Long Island City    NY  11101
# 9         Ivan Layton      211 Hardesty Street            Albany    NY  12207
#
#   Birth Date  Birth Year     Telephone Area Code  \
# 0 1999-07-27        1999  618-376-3064       618
# ...
